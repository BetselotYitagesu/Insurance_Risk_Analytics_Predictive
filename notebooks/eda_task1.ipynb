# %% [markdown]
# ### EDA -- Exploratory Data Analysis

# %%
# Import Necessary Package 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Process raw Data...

data_path = "../data/raw/insurance_data.csv"  

# Read CSV with '|' delimiter
df = pd.read_csv(data_path, sep='|', encoding='utf-8')

print("Shape:", df.shape)
df.head()
# Out:
# C:\Users\betsi\AppData\Local\Temp\ipykernel_14760\2638380567.py:6: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, sep='|', encoding='utf-8')
# Shape: (1000098, 52)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# for col in df.columns:
#     print(f"{col}: {df[col].unique()[:10]}")  # Show first 5 unique values

# %%
# Check statistical USmmery of the data
df.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
# Check Missing Values
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# NumberOfVehiclesInFleet    1000098
# CrossBorder                 999400
# CustomValueEstimate         779642
# Rebuilt                     641901
# Converted                   641901
# WrittenOff                  641901
# NewVehicle                  153295
# Bank                        145961
# AccountType                  40232
# Gender                        9536
# MaritalStatus                 8259
# VehicleType                    552
# make                           552
# mmcode                         552
# Model                          552
# Cylinders                      552
# bodytype                       552
# kilowatts                      552
# NumberOfDoors                  552
# VehicleIntroDate               552
# cubiccapacity                  552
# CapitalOutstanding               2
# dtype: int64

# %%
import sys
sys.path.append("../src") 

from core.cleaning import clean_insurance_data

df = clean_insurance_data(df)
df.isnull().sum().sort_values(ascending=False).head(10)  # Check remaining missing values
# Out:
# NumberOfVehiclesInFleet    1000096
# Bank                        145959
# AccountType                  40230
# make                           552
# Model                          552
# Cylinders                      552
# kilowatts                      552
# cubiccapacity                  552
# UnderwrittenCoverID              0
# Language                         0
# dtype: int64

# %%
# Convert Dates
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'], errors='coerce')

# %%
df.isnull().sum().sort_values(ascending=False).head(10)  # Check remaining missing values
# Out:
# NumberOfVehiclesInFleet    1000096
# Bank                        145959
# AccountType                  40230
# make                           552
# Model                          552
# Cylinders                      552
# kilowatts                      552
# cubiccapacity                  552
# UnderwrittenCoverID              0
# Language                         0
# dtype: int64

# %%
# df['NumberOfVehiclesInFleet'].unique(), df['Bank'].unique(), df['AccountType'].unique(),df['make'].unique()

# %%
# df['Model'].unique(), df['Cylinders'].unique()

# %%
# df['kilowatts'].unique(),df['cubiccapacity'].unique()

# %%
# # Drop Columns with Too Much Missing Data... given the previous outputs
df.drop(columns=['NumberOfVehiclesInFleet'], inplace=True)

# Fill missing with "Unknown" (or "Other" if preferred).

df['Bank'] = df['Bank'].fillna('Unknown')
df['AccountType'] = df['AccountType'].fillna('Unknown')

# Clean make, Model, Cylinders, kilowatts, cubiccapacity

df['make'] = df['make'].str.strip().fillna('Unknown')
df['Model'] = df['Model'].fillna('Unknown')
df['Cylinders'] = df['Cylinders'].fillna(-1)
df['kilowatts'] = df['kilowatts'].fillna(-1)
df['cubiccapacity'] = df['cubiccapacity'].fillna(-1)

# Fill NaN with 'Unknown' or 'No' (if you assume default is 'No').
df['CrossBorder'] = df['CrossBorder'].fillna('No')


df['VehicleIntroDate'] = df['VehicleIntroDate'].fillna('Unknown')  # if string/date
df['NumberOfDoors'] = df['NumberOfDoors'].fillna(-1)
df['mmcode'] = df['mmcode'].fillna('Unknown')
df['bodytype'] = df['bodytype'].fillna('Unknown')

# %%
df.isnull().sum().sort_values(ascending=False).head(10)  # Check remaining missing values
# Out:
# NewVehicle             1000096
# UnderwrittenCoverID          0
# TransactionMonth             0
# PolicyID                     0
# Citizenship                  0
# LegalType                    0
# Title                        0
# IsVATRegistered              0
# Bank                         0
# AccountType                  0
# dtype: int64

# %%
# # Impute Remaining Moderate Gaps

# df['NewVehicle'] = df['NewVehicle'].fillna('No')
# df['NewVehicle'] = df['NewVehicle'].map({'Yes': 1, 'No': 0})

# num_cols = ['kilowatts', 'Cylinders', 'cubiccapacity']
# for col in num_cols:
#     if col in df.columns:
#         df[col] = df[col].fillna(df[col].median())


# cat_cols = ['make', 'Model']
# for col in cat_cols:
#     if col in df.columns:
#         df[col] = df[col].fillna(df[col].mode()[0])

# %%
df['NewVehicle'].unique()
# Out:
# array([nan], dtype=object)

# %%
df.isnull().sum().sort_values(ascending=False).head(10)  # Check remaining missing values
# Out:
# NewVehicle             1000096
# UnderwrittenCoverID          0
# TransactionMonth             0
# PolicyID                     0
# Citizenship                  0
# LegalType                    0
# Title                        0
# IsVATRegistered              0
# Bank                         0
# AccountType                  0
# dtype: int64
